# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Feb  4 03:31:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0    26W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install openai pytube -q
# !pip install git+https://github.com/openai/whisper.git -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 KB 4.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 7.4 MB/s eta 0:00:00
#   Building wheel for openai (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 87.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 24.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 113.9 MB/s eta 0:00:00
#   Building wheel for openai-whisper (setup.py) ... done

# %%
import openai
import whisper
import pandas as pd
from pytube import YouTube
from getpass import getpass

COMPLETIONS_MODEL = "text-davinci-003"
EMBEDDINGS_MODEL = "text-embedding-ada-002"
openai.api_key = getpass("Enter your OpenAI API Key")
# Out:
# Enter your OpenAI API Key··········

# %%
model = whisper.load_model('base')
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:01<00:00, 81.8MiB/s]

# %%
youtube_video_url = "https://www.youtube.com/watch?v=OYxhrPdZdog"
youtube_video = YouTube(youtube_video_url)

# %%
dir(youtube_video)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'from_id',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
#  'publish_date',
#  'rating',
#  'register_on_complete_callback',
#  'register_on_progress_callback',
#  'stream_monostate',
#  'streaming_data',
#  'streams',
#  'thumbnail_url',
#  'title',
#  'use_oauth',
#  'vid_info',
#  'video_id',
#  'views',
#  'watch_html',
#  'watch_url']

# %%
stream = youtube_video.streams.filter(only_audio=True).first()
stream.download(filename='financial_advisor.mp4')
# Out:
# '/content/financial_advisor.mp4'

# %%
youtube_video.description
# Out:
# "Welcome to Portfolio Rescue, the show where we answer your questions about investing and personal finance. On this episode, Ben and Duncan are joined by RWM advisor, Matt Lohrius. Submit your questions to askthecompoundshow@gmail.com!\n\n► 00:00 - Intro\n► 01:58 - How does the fed raising interest rates fights off inflation?\n► 03:30 - What particular sectors/names do you find most compelling for a young investor with a 35-40 year time horizon?\n► 05:16 - What will bring more value in the long run for a child?\n► 10:18 - Would you recommend focusing on paying off my student loans first? Or should I begin building my portfolio? \n► 11:57 - Paying off a mortgage.\n► 13:25 - What happens when the Fed raises rates?\n► 14:39 - I’m 44 and have a net worth of around $425K. Would have more if TWTR didn’t crash, I didn’t sell any - I own 5,550 shares at @ $29.83 cost basis. What do you think about where I am? \n► 17:19 - What are some good questions to ask when selecting a financial advisor, especially as a young person?\n► 21:15 -  At interest rates so low, should I instead take a loan, finance the house and invest my capital in the stock market?\n \nSign up for The Compound newsletter: https://email.thecompoundnews.com/subscribe\n\nCheck out The Compound shop: https://www.idontshop.com\n\nInvesting involves the risk of loss. This podcast is for informational purposes only and should not be regarded as personalized investment advice or relied upon for investment decisions. Ben Carlson, Matt Lohrius, and Duncan Hill are employees of Ritholtz Wealth Management and may maintain positions in the securities discussed in this video. All opinions expressed by Ben and guests are solely their own opinions and do not reflect the opinion of Ritholtz Wealth Management. See a complete list of disclosures here:\nhttps://ritholtzwealth.com/podcast-youtube-disclosures/\n\nListen to our podcasts:\nThe Compound and Friends: https://link.chtbl.com/compoundandfriends\nAnimal Spirits: https://podcasts.apple.com/us/podcast/animal-spirits-podcast/id1310192007\nPortfolio Rescue: https://link.chtbl.com/totherescue\n\nTalk with us about your portfolio or financial plan here: http://ritholtzwealth.com\n\nCheck out Ritholtz Wealth's automated investing platform, Liftoff: http://liftoffinvest.com\n\nInstagram: https://instagram.com/thecompoundnews\nTwitter: https://twitter.com/thecompoundnews\nFacebook: https://www.facebook.com/ritholtzwealth\n\n#investing #thecompound #personalfinance"

# %%
output = model.transcribe("financial_advisor.mp4")

# %%
output
# Out:
# {'text': " Welcome back to Portfolio Rescue. I'll show you where we take questions straight from you. We've got a lot of questions like I said last week. We're going to try to do a lightning round today. Before we get to that, I remember asked the compound show at gmail.com Duncan. Last week's show I mentioned the 50-30-20 rule. I said, I don't know where it comes from. A lot of these things in finance, they just sound good and they stick like the 60-40 Portfolio. No one actually knows who started that or where it came from. We all just kind of subscribed to it. But the 50-30-20 rule. Last Thursday after we did the show, I was reading a book at night, kind of read before I go to bed. I was reading this book called Die Was Zero by a guy named Bill Perkins. The whole idea is if you have a lot of money, your hope should be to spend that money, either give it away to charity or spend it all on experiences before you die. Interesting concept. A lot. You were talking about animal spirits. Yeah, one of the chapters of that same book. He said, the 50-30-20 rule comes from a very well-known politician today. It's a woman. Do you have any guesses? A politician came up with this. Elizabeth Warren? Elizabeth Warren. Before Shanner Pilatex, Warren had been a law professor with special expertise in bankruptcy in Coral Books about why middle-class Americans go broke and how to avoid that dismal fate. She suggested the 50-30-20 rule, which she called the balanced money formula as a way to help people maintain financial stability. It had no idea. This was Elizabeth Warren rule. Yeah. It's going to be crazy. All right. So we're just going to get right into it because last week we mentioned we're overflowing with questions. So we're going to do something about lightning around today. Rapid fire. We still have an expert coming out at the end of the show. But I think we did seven or eight questions right away. We're just going to go rapid fire. We had a lot of them and I don't need spend a ton of time. So I think Doug has got a timer for me, even. Yeah. He's going to have a timer too long. I'm going to time you on the Apple Watch and I've actually got a sound effect timer and buzzer. All right. Question one. OK. OK. OK. Can you please explain how the Fed raising interest rates fights off inflation? I understand it can slow down the housing and car market. But how does it impact other goods? Bikes, dishwashers, clothes, et cetera, especially when there are supply side issues? Would the Fed be raising rates if demand and supply were at equilibrium? This is true that the Fed can't produce more. Some of the conductors, they can't build more houses. They can't put more cars in the lots. Here's one of the things they can do. They can make money more expensive. So maybe people don't buy a second home because instead of 3% it's 5%, I'm not going to pay for another house here. I'm not going to buy a vacation home. Maybe some companies cut back on investments because the hurdle rate is not much higher. I think it's also psychological component to this. People see asset prices falling and they might cut back on spending. He'll Dudley who's a former New York Fed chair, wrote yesterday in Bloomberg. In contrast to many other countries, the US economy doesn't respond directly to the level of short-term interest rates. The home borrowers aren't affected because they have long-term fixed rate mortgages. Again, in contrast to many other countries, US households do hold a significant amount of wealth and equities. As a result, their sensitive financial conditions, equity price influence how wealthy people feel and how willing they are to spend rather than save. He's saying the Fed has to jack up rates to lower the stock market. That makes sense. I don't know what the unintended consequences are going to be. Is a recession going to be better than high inflation? I think we might get a chance to find out if the Fed has their way. The Fed can't make supply chain issue ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 19.080000000000002,
#    'text': ' Welcome back to Portfolio Rescue.',
#    'tokens': [4027, 646, 281, 6733, 7082, 1004, 39379, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.36206009513453435,
#    'compression_ratio': 1.4491978609625669,
#    'no_speech_prob': 0.19078688323497772},
#   {'id': 1,
#    'seek': 0,
#    'start': 19.080000000000002,
#    'end': 21.080000000000002,
#    'text': " I'll show you where we take questions straight from you.",
#    'tokens': [286, 603, 855, 291, 689, 321, 747, 1651, 2997, 490, 291, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.36206009513453435,
#    'compression_ratio': 1.4491978609625669,
#    'no_speech_prob': 0.19078688323497772},
#   {'id': 2,
#    'seek': 0,
#    'start': 21.080000000000002,
#    'end': 23.48,
#    'text': " We've got a lot of questions like I said last week.",
#    'tokens': [492,
#     600,
#     658,
#     257,
#     688,
#     295,
#     1651,
#     411,
#     286,
#     848,
#     1036,
#     1243,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.36206009513453435,
#    'compression_ratio': 1.4491978609625669,
#    'no_speech_prob': 0.19078688323497772},
#   {'id': 3,
#    'seek': 0,
#    'start': 23.48,
#    'end': 26.080000000000002,
#    'text': " We're going to try to do a lightning round today.",
#    'tokens': [492, 434, 516, 281, 853, 281, 360, 257, 16589, 3098, 965, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.36206009513453435,
#    'compression_ratio': 1.4491978609625669,
#    'no_speech_prob': 0.19078688323497772},
#   {'id': 4,
#    'seek': 0,
#    'start': 26.080000000000002,
#    'end': 29.84,
#    'text': ' Before we get to that, I remember asked the compound show at gmail.com Duncan.',
#    'tokens': [4546,
#     321,
#     483,
#     281,
#     300,
#     11,
#     286,
#     1604,
#     2351,
#     264,
#     14154,
#     855,
#     412,
#     290,
#     11799,
#     13,
#     1112,
#     31942,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.36206009513453435,
#    'compression_ratio': 1.4491978609625669,
#    'no_speech_prob': 0.19078688323497772},
#   {'id': 5,
#    'seek': 2984,
#    'start': 29.84,
#    'end': 32.16,
#    'text': " Last week's show I mentioned the 50-30-20 rule.",
#    'tokens': [5264,
#     1243,
#     311,
#     855,
#     286,
#     2835,
#     264,
#     2625,
#     12,
#     3446,
#     12,
#     2009,
#     4978,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 6,
#    'seek': 2984,
#    'start': 32.16,
#    'end': 34.16,
#    'text': " I said, I don't know where it comes from.",
#    'tokens': [286, 848, 11, 286, 500, 380, 458, 689, 309, 1487, 490, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 7,
#    'seek': 2984,
#    'start': 34.16,
#    'end': 38.28,
#    'text': ' A lot of these things in finance, they just sound good and they stick like the 60-40 Portfolio.',
#    'tokens': [316,
#     688,
#     295,
#     613,
#     721,
#     294,
#     10719,
#     11,
#     436,
#     445,
#     1626,
#     665,
#     293,
#     436,
#     2897,
#     411,
#     264,
#     4060,
#     12,
#     5254,
#     6733,
#     7082,
#     1004,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 8,
#    'seek': 2984,
#    'start': 38.28,
#    'end': 41.08,
#    'text': ' No one actually knows who started that or where it came from.',
#    'tokens': [883,
#     472,
#     767,
#     3255,
#     567,
#     1409,
#     300,
#     420,
#     689,
#     309,
#     1361,
#     490,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 9,
#    'seek': 2984,
#    'start': 41.08,
#    'end': 42.92,
#    'text': ' We all just kind of subscribed to it.',
#    'tokens': [492, 439, 445, 733, 295, 16665, 281, 309, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 10,
#    'seek': 2984,
#    'start': 42.92,
#    'end': 45.0,
#    'text': ' But the 50-30-20 rule.',
#    'tokens': [583, 264, 2625, 12, 3446, 12, 2009, 4978, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 11,
#    'seek': 2984,
#    'start': 45.0,
#    'end': 48.28,
#    'text': ' Last Thursday after we did the show, I was reading a book at night, kind of read before',
#    'tokens': [5264,
#     10383,
#     934,
#     321,
#     630,
#     264,
#     855,
#     11,
#     286,
#     390,
#     3760,
#     257,
#     1446,
#     412,
#     1818,
#     11,
#     733,
#     295,
#     1401,
#     949],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 12,
#    'seek': 2984,
#    'start': 48.28,
#    'end': 49.28,
#    'text': ' I go to bed.',
#    'tokens': [286, 352, 281, 2901, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 13,
#    'seek': 2984,
#    'start': 49.28,
#    'end': 51.6,
#    'text': ' I was reading this book called Die Was Zero by a guy named Bill Perkins.',
#    'tokens': [286,
#     390,
#     3760,
#     341,
#     1446,
#     1219,
#     3229,
#     3027,
#     17182,
#     538,
#     257,
#     2146,
#     4926,
#     5477,
#     3026,
#     10277,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 14,
#    'seek': 2984,
#    'start': 51.6,
#    'end': 55.04,
#    'text': ' The whole idea is if you have a lot of money, your hope should be to spend that money,',
#    'tokens': [440,
#     1379,
#     1558,
#     307,
#     498,
#     291,
#     362,
#     257,
#     688,
#     295,
#     1460,
#     11,
#     428,
#     1454,
#     820,
#     312,
#     281,
#     3496,
#     300,
#     1460,
#     11],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 15,
#    'seek': 2984,
#    'start': 55.04,
#    'end': 58.519999999999996,
#    'text': ' either give it away to charity or spend it all on experiences before you die.',
#    'tokens': [2139,
#     976,
#     309,
#     1314,
#     281,
#     16863,
#     420,
#     3496,
#     309,
#     439,
#     322,
#     5235,
#     949,
#     291,
#     978,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 16,
#    'seek': 2984,
#    'start': 58.519999999999996,
#    'end': 59.519999999999996,
#    'text': ' Interesting concept.',
#    'tokens': [14711, 3410, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24222845249075106,
#    'compression_ratio': 1.691139240506329,
#    'no_speech_prob': 0.00024530405062250793},
#   {'id': 17,
#    'seek': 5952,
#    'start': 59.52,
#    'end': 60.52,
#    'text': ' A lot.',
#    'tokens': [316, 688, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 18,
#    'seek': 5952,
#    'start': 60.52,
#    'end': 61.52,
#    'text': ' You were talking about animal spirits.',
#    'tokens': [509, 645, 1417, 466, 5496, 16388, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 19,
#    'seek': 5952,
#    'start': 61.52,
#    'end': 63.6,
#    'text': ' Yeah, one of the chapters of that same book.',
#    'tokens': [865, 11, 472, 295, 264, 20013, 295, 300, 912, 1446, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 20,
#    'seek': 5952,
#    'start': 63.6,
#    'end': 68.4,
#    'text': ' He said, the 50-30-20 rule comes from a very well-known politician today.',
#    'tokens': [634,
#     848,
#     11,
#     264,
#     2625,
#     12,
#     3446,
#     12,
#     2009,
#     4978,
#     1487,
#     490,
#     257,
#     588,
#     731,
#     12,
#     6861,
#     26453,
#     965,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 21,
#    'seek': 5952,
#    'start': 68.4,
#    'end': 69.4,
#    'text': " It's a woman.",
#    'tokens': [467, 311, 257, 3059, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 22,
#    'seek': 5952,
#    'start': 69.4,
#    'end': 70.4,
#    'text': ' Do you have any guesses?',
#    'tokens': [1144, 291, 362, 604, 42703, 30],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 23,
#    'seek': 5952,
#    'start': 70.4,
#    'end': 72.4,
#    'text': ' A politician came up with this.',
#    'tokens': [316, 26453, 1361, 493, 365, 341, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 24,
#    'seek': 5952,
#    'start': 72.4,
#    'end': 73.4,
#    'text': ' Elizabeth Warren?',
#    'tokens': [12978, 20538, 30],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 25,
#    'seek': 5952,
#    'start': 73.4,
#    'end': 75.24000000000001,
#    'text': ' Elizabeth Warren.',
#    'tokens': [12978, 20538, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 26,
#    'seek': 5952,
#    'start': 75.24000000000001,
#    'end': 79.0,
#    'text': ' Before Shanner Pilatex, Warren had been a law professor with special expertise in bankruptcy',
#    'tokens': [4546,
#     1160,
#     9805,
#     18026,
#     473,
#     87,
#     11,
#     20538,
#     632,
#     668,
#     257,
#     2101,
#     8304,
#     365,
#     2121,
#     11769,
#     294,
#     33457],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 27,
#    'seek': 5952,
#    'start': 79.0,
#    'end': 83.52000000000001,
#    'text': ' in Coral Books about why middle-class Americans go broke and how to avoid that dismal fate.',
#    'tokens': [294,
#     3925,
#     304,
#     33843,
#     466,
#     983,
#     2808,
#     12,
#     11665,
#     6280,
#     352,
#     6902,
#     293,
#     577,
#     281,
#     5042,
#     300,
#     717,
#     5579,
#     12738,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 28,
#    'seek': 5952,
#    'start': 83.52000000000001,
#    'end': 88.12,
#    'text': ' She suggested the 50-30-20 rule, which she called the balanced money formula as a way to',
#    'tokens': [1240,
#     10945,
#     264,
#     2625,
#     12,
#     3446,
#     12,
#     2009,
#     4978,
#     11,
#     597,
#     750,
#     1219,
#     264,
#     13902,
#     1460,
#     8513,
#     382,
#     257,
#     636,
#     281],
#    'temperature': 0.0,
#    'avg_logprob': -0.2079293333142009,
#    'compression_ratio': 1.5889212827988337,
#    'no_speech_prob': 0.0018673177110031247},
#   {'id': 29,
#    'seek': 8812,
#    'start': 88.12,
#    'end': 90.12,
#    'text': ' help people maintain financial stability.',
#    'tokens': [854, 561, 6909, 4669, 11826, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 30,
#    'seek': 8812,
#    'start': 90.12,
#    'end': 91.12,
#    'text': ' It had no idea.',
#    'tokens': [467, 632, 572, 1558, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 31,
#    'seek': 8812,
#    'start': 91.12,
#    'end': 92.12,
#    'text': ' This was Elizabeth Warren rule.',
#    'tokens': [639, 390, 12978, 20538, 4978, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 32,
#    'seek': 8812,
#    'start': 92.12,
#    'end': 93.12,
#    'text': ' Yeah.',
#    'tokens': [865, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 33,
#    'seek': 8812,
#    'start': 93.12,
#    'end': 94.12,
#    'text': " It's going to be crazy.",
#    'tokens': [467, 311, 516, 281, 312, 3219, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 34,
#    'seek': 8812,
#    'start': 94.12,
#    'end': 95.12,
#    'text': ' All right.',
#    'tokens': [1057, 558, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 35,
#    'seek': 8812,
#    'start': 95.12,
#    'end': 96.76,
#    'text': " So we're just going to get right into it because last week we mentioned we're overflowing",
#    'tokens': [407,
#     321,
#     434,
#     445,
#     516,
#     281,
#     483,
#     558,
#     666,
#     309,
#     570,
#     1036,
#     1243,
#     321,
#     2835,
#     321,
#     434,
#     670,
#     43955],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 36,
#    'seek': 8812,
#    'start': 96.76,
#    'end': 97.76,
#    'text': ' with questions.',
#    'tokens': [365, 1651, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 37,
#    'seek': 8812,
#    'start': 97.76,
#    'end': 100.36,
#    'text': " So we're going to do something about lightning around today.",
#    'tokens': [407, 321, 434, 516, 281, 360, 746, 466, 16589, 926, 965, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 38,
#    'seek': 8812,
#    'start': 100.36,
#    'end': 101.36,
#    'text': ' Rapid fire.',
#    'tokens': [44580, 2610, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 39,
#    'seek': 8812,
#    'start': 101.36,
#    'end': 103.04,
#    'text': ' We still have an expert coming out at the end of the show.',
#    'tokens': [492,
#     920,
#     362,
#     364,
#     5844,
#     1348,
#     484,
#     412,
#     264,
#     917,
#     295,
#     264,
#     855,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 40,
#    'seek': 8812,
#    'start': 103.04,
#    'end': 105.12,
#    'text': ' But I think we did seven or eight questions right away.',
#    'tokens': [583, 286, 519, 321, 630, 3407, 420, 3180, 1651, 558, 1314, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 41,
#    'seek': 8812,
#    'start': 105.12,
#    'end': 106.12,
#    'text': " We're just going to go rapid fire.",
#    'tokens': [492, 434, 445, 516, 281, 352, 7558, 2610, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 42,
#    'seek': 8812,
#    'start': 106.12,
#    'end': 107.92,
#    'text': " We had a lot of them and I don't need spend a ton of time.",
#    'tokens': [492,
#     632,
#     257,
#     688,
#     295,
#     552,
#     293,
#     286,
#     500,
#     380,
#     643,
#     3496,
#     257,
#     2952,
#     295,
#     565,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 43,
#    'seek': 8812,
#    'start': 107.92,
#    'end': 110.4,
#    'text': ' So I think Doug has got a timer for me, even.',
#    'tokens': [407,
#     286,
#     519,
#     12742,
#     575,
#     658,
#     257,
#     19247,
#     337,
#     385,
#     11,
#     754,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 44,
#    'seek': 8812,
#    'start': 110.4,
#    'end': 111.4,
#    'text': ' Yeah.',
#    'tokens': [865, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 45,
#    'seek': 8812,
#    'start': 111.4,
#    'end': 112.4,
#    'text': " He's going to have a timer too long.",
#    'tokens': [634, 311, 516, 281, 362, 257, 19247, 886, 938, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 46,
#    'seek': 8812,
#    'start': 112.4,
#    'end': 115.56,
#    'text': " I'm going to time you on the Apple Watch and I've actually got a sound effect timer",
#    'tokens': [286,
#     478,
#     516,
#     281,
#     565,
#     291,
#     322,
#     264,
#     6373,
#     7277,
#     293,
#     286,
#     600,
#     767,
#     658,
#     257,
#     1626,
#     1802,
#     19247],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 47,
#    'seek': 8812,
#    'start': 115.56,
#    'end': 116.56,
#    'text': ' and buzzer.',
#    'tokens': [293, 13036, 260, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 48,
#    'seek': 8812,
#    'start': 116.56,
#    'end': 117.56,
#    'text': ' All right.',
#    'tokens': [1057, 558, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2301798815975822,
#    'compression_ratio': 1.8402061855670102,
#    'no_speech_prob': 0.00045822816900908947},
#   {'id': 49,
#    'seek': 11756,
#    'start': 117.56,
#    'end': 118.56,
#    'text': ' Question one.',
#    'tokens': [14464, 472, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 50,
#    'seek': 11756,
#    'start': 118.56,
#    'end': 119.56,
#    'text': ' OK.',
#    'tokens': [2264, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 51,
#    'seek': 11756,
#    'start': 119.56,
#    'end': 120.56,
#    'text': ' OK.',
#    'tokens': [2264, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 52,
#    'seek': 11756,
#    'start': 120.56,
#    'end': 121.56,
#    'text': ' OK.',
#    'tokens': [2264, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 53,
#    'seek': 11756,
#    'start': 121.56,
#    'end': 125.56,
#    'text': ' Can you please explain how the Fed raising interest rates fights off inflation?',
#    'tokens': [1664,
#     291,
#     1767,
#     2903,
#     577,
#     264,
#     7772,
#     11225,
#     1179,
#     6846,
#     14512,
#     766,
#     15860,
#     30],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 54,
#    'seek': 11756,
#    'start': 125.56,
#    'end': 128.16,
#    'text': ' I understand it can slow down the housing and car market.',
#    'tokens': [286, 1223, 309, 393, 2964, 760, 264, 6849, 293, 1032, 2142, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 55,
#    'seek': 11756,
#    'start': 128.16,
#    'end': 129.92000000000002,
#    'text': ' But how does it impact other goods?',
#    'tokens': [583, 577, 775, 309, 2712, 661, 10179, 30],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 56,
#    'seek': 11756,
#    'start': 129.92000000000002,
#    'end': 134.6,
#    'text': ' Bikes, dishwashers, clothes, et cetera, especially when there are supply side issues?',
#    'tokens': [363,
#     8916,
#     11,
#     5025,
#     38558,
#     433,
#     11,
#     5534,
#     11,
#     1030,
#     11458,
#     11,
#     2318,
#     562,
#     456,
#     366,
#     5847,
#     1252,
#     2663,
#     30],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 57,
#    'seek': 11756,
#    'start': 134.6,
#    'end': 138.6,
#    'text': ' Would the Fed be raising rates if demand and supply were at equilibrium?',
#    'tokens': [6068,
#     264,
#     7772,
#     312,
#     11225,
#     6846,
#     498,
#     4733,
#     293,
#     5847,
#     645,
#     412,
#     15625,
#     30],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 58,
#    'seek': 11756,
#    'start': 138.6,
#    'end': 140.76,
#    'text': " This is true that the Fed can't produce more.",
#    'tokens': [639, 307, 2074, 300, 264, 7772, 393, 380, 5258, 544, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 59,
#    'seek': 11756,
#    'start': 140.76,
#    'end': 142.16,
#    'text': " Some of the conductors, they can't build more houses.",
#    'tokens': [2188,
#     295,
#     264,
#     6018,
#     830,
#     11,
#     436,
#     393,
#     380,
#     1322,
#     544,
#     8078,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 60,
#    'seek': 11756,
#    'start': 142.16,
#    'end': 145.08,
#    'text': " They can't put more cars in the lots.",
#    'tokens': [814, 393, 380, 829, 544, 5163, 294, 264, 3195, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 61,
#    'seek': 11756,
#    'start': 145.08,
#    'end': 146.08,
#    'text': " Here's one of the things they can do.",
#    'tokens': [1692, 311, 472, 295, 264, 721, 436, 393, 360, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21620511048592178,
#    'compression_ratio': 1.6952380952380952,
#    'no_speech_prob': 0.0014100776752457023},
#   {'id': 62,
#    'seek': 14608,
#    'start': 146.08,
#    'end': 147.64000000000001,
#    'text': ' They can make money more expensive.',
#    'tokens': [814, 393, 652, 1460, 544, 5124, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 63,
#    'seek': 14608,
#    'start': 147.64000000000001,
#    'end': 152.92000000000002,
#    'text': " So maybe people don't buy a second home because instead of 3% it's 5%, I'm not going to",
#    'tokens': [407,
#     1310,
#     561,
#     500,
#     380,
#     2256,
#     257,
#     1150,
#     1280,
#     570,
#     2602,
#     295,
#     805,
#     4,
#     309,
#     311,
#     1025,
#     8923,
#     286,
#     478,
#     406,
#     516,
#     281],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 64,
#    'seek': 14608,
#    'start': 152.92000000000002,
#    'end': 153.92000000000002,
#    'text': ' pay for another house here.',
#    'tokens': [1689, 337, 1071, 1782, 510, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 65,
#    'seek': 14608,
#    'start': 153.92000000000002,
#    'end': 155.32000000000002,
#    'text': " I'm not going to buy a vacation home.",
#    'tokens': [286, 478, 406, 516, 281, 2256, 257, 12830, 1280, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 66,
#    'seek': 14608,
#    'start': 155.32000000000002,
#    'end': 159.84,
#    'text': ' Maybe some companies cut back on investments because the hurdle rate is not much higher.',
#    'tokens': [2704,
#     512,
#     3431,
#     1723,
#     646,
#     322,
#     13784,
#     570,
#     264,
#     47423,
#     3314,
#     307,
#     406,
#     709,
#     2946,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 67,
#    'seek': 14608,
#    'start': 159.84,
#    'end': 162.72000000000003,
#    'text': " I think it's also psychological component to this.",
#    'tokens': [286, 519, 309, 311, 611, 14346, 6542, 281, 341, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 68,
#    'seek': 14608,
#    'start': 162.72000000000003,
#    'end': 165.60000000000002,
#    'text': ' People see asset prices falling and they might cut back on spending.',
#    'tokens': [3432,
#     536,
#     11999,
#     7901,
#     7440,
#     293,
#     436,
#     1062,
#     1723,
#     646,
#     322,
#     6434,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 69,
#    'seek': 14608,
#    'start': 165.60000000000002,
#    'end': 169.84,
#    'text': " He'll Dudley who's a former New York Fed chair, wrote yesterday in Bloomberg.",
#    'tokens': [634,
#     603,
#     42622,
#     3420,
#     567,
#     311,
#     257,
#     5819,
#     1873,
#     3609,
#     7772,
#     6090,
#     11,
#     4114,
#     5186,
#     294,
#     40363,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 70,
#    'seek': 14608,
#    'start': 169.84,
#    'end': 173.4,
#    'text': " In contrast to many other countries, the US economy doesn't respond directly to the level",
#    'tokens': [682,
#     8712,
#     281,
#     867,
#     661,
#     3517,
#     11,
#     264,
#     2546,
#     5010,
#     1177,
#     380,
#     4196,
#     3838,
#     281,
#     264,
#     1496],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 71,
#    'seek': 14608,
#    'start': 173.4,
#    'end': 174.92000000000002,
#    'text': ' of short-term interest rates.',
#    'tokens': [295, 2099, 12, 7039, 1179, 6846, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.22691178801875786,
#    'compression_ratio': 1.6195652173913044,
#    'no_speech_prob': 0.00010719808778958395},
#   {'id': 72,
#    'seek': 17492,
#    'start': 174.92,
#    'end': 177.83999999999997,
#    'text': " The home borrowers aren't affected because they have long-term fixed rate mortgages.",
#    'tokens': [440,
#     1280,
#     11172,
#     433,
#     3212,
#     380,
#     8028,
#     570,
#     436,
#     362,
#     938,
#     12,
#     7039,
#     6806,
#     3314,
#     6599,
#     70,
#     1660,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 73,
#    'seek': 17492,
#    'start': 177.83999999999997,
#    'end': 181.39999999999998,
#    'text': ' Again, in contrast to many other countries, US households do hold a significant amount',
#    'tokens': [3764,
#     11,
#     294,
#     8712,
#     281,
#     867,
#     661,
#     3517,
#     11,
#     2546,
#     22850,
#     360,
#     1797,
#     257,
#     4776,
#     2372],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 74,
#    'seek': 17492,
#    'start': 181.39999999999998,
#    'end': 182.76,
#    'text': ' of wealth and equities.',
#    'tokens': [295, 7203, 293, 1267, 1088, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 75,
#    'seek': 17492,
#    'start': 182.76,
#    'end': 187.2,
#    'text': ' As a result, their sensitive financial conditions, equity price influence how wealthy people feel',
#    'tokens': [1018,
#     257,
#     1874,
#     11,
#     641,
#     9477,
#     4669,
#     4487,
#     11,
#     10769,
#     3218,
#     6503,
#     577,
#     17707,
#     561,
#     841],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 76,
#    'seek': 17492,
#    'start': 187.2,
#    'end': 189.6,
#    'text': ' and how willing they are to spend rather than save.',
#    'tokens': [293, 577, 4950, 436, 366, 281, 3496, 2831, 813, 3155, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 77,
#    'seek': 17492,
#    'start': 189.6,
#    'end': 193.44,
#    'text': " He's saying the Fed has to jack up rates to lower the stock market.",
#    'tokens': [634,
#     311,
#     1566,
#     264,
#     7772,
#     575,
#     281,
#     7109,
#     493,
#     6846,
#     281,
#     3126,
#     264,
#     4127,
#     2142,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 78,
#    'seek': 17492,
#    'start': 193.44,
#    'end': 194.44,
#    'text': ' That makes sense.',
#    'tokens': [663, 1669, 2020, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 79,
#    'seek': 17492,
#    'start': 194.44,
#    'end': 196.6,
#    'text': " I don't know what the unintended consequences are going to be.",
#    'tokens': [286,
#     500,
#     380,
#     458,
#     437,
#     264,
#     49902,
#     10098,
#     366,
#     516,
#     281,
#     312,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 80,
#    'seek': 17492,
#    'start': 196.6,
#    'end': 198.92,
#    'text': ' Is a recession going to be better than high inflation?',
#    'tokens': [1119, 257, 24828, 516, 281, 312, 1101, 813, 1090, 15860, 30],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 81,
#    'seek': 17492,
#    'start': 198.92,
#    'end': 202.11999999999998,
#    'text': ' I think we might get a chance to find out if the Fed has their way.',
#    'tokens': [286,
#     519,
#     321,
#     1062,
#     483,
#     257,
#     2931,
#     281,
#     915,
#     484,
#     498,
#     264,
#     7772,
#     575,
#     641,
#     636,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2215181312813664,
#    'compression_ratio': 1.7044198895027625,
#    'no_speech_prob': 0.00024532232782803476},
#   {'id': 82,
#    'seek': 20212,
#    'start': 202.12,
#    'end': 207.20000000000002,
#    'text': " The Fed can't make supply chain issues go better, get back without helping demand.",
#    'tokens': [440,
#     7772,
#     393,
#     380,
#     652,
#     5847,
#     5021,
#     2663,
#     352,
#     1101,
#     11,
#     483,
#     646,
#     1553,
#     4315,
#     4733,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 83,
#    'seek': 20212,
#    'start': 207.20000000000002,
#    'end': 208.20000000000002,
#    'text': ' A lot of pressure.',
#    'tokens': [316, 688, 295, 3321, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 84,
#    'seek': 20212,
#    'start': 208.20000000000002,
#    'end': 209.20000000000002,
#    'text': ' All right.',
#    'tokens': [1057, 558, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 85,
#    'seek': 20212,
#    'start': 209.20000000000002,
#    'end': 210.20000000000002,
#    'text': ' Up to the next one.',
#    'tokens': [5858, 281, 264, 958, 472, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 86,
#    'seek': 20212,
#    'start': 210.20000000000002,
#    'end': 211.20000000000002,
#    'text': ' Shyclot.',
#    'tokens': [45250, 3474, 310, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 87,
#    'seek': 20212,
#    'start': 211.20000000000002,
#    'end': 212.20000000000002,
#    'text': ' That was pretty close.',
#    'tokens': [663, 390, 1238, 1998, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 88,
#    'seek': 20212,
#    'start': 212.20000000000002,
#    'end': 213.20000000000002,
#    'text': ' All right.',
#    'tokens': [1057, 558, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 89,
#    'seek': 20212,
#    'start': 213.20000000000002,
#    'end': 214.20000000000002,
#    'text': ' Next one.',
#    'tokens': [3087, 472, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 90,
#    'seek': 20212,
#    'start': 214.20000000000002,
#    'end': 216.04,
#    'text': ' The best thing about the Fed, too, is you can always blame the Fed, right?',
#    'tokens': [440,
#     1151,
#     551,
#     466,
#     264,
#     7772,
#     11,
#     886,
#     11,
#     307,
#     291,
#     393,
#     1009,
#     10127,
#     264,
#     7772,
#     11,
#     558,
#     30],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 91,
#    'seek': 20212,
#    'start': 216.04,
#    'end': 217.04,
#    'text': " If things don't go your way.",
#    'tokens': [759, 721, 500, 380, 352, 428, 636, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 92,
#    'seek': 20212,
#    'start': 217.04,
#    'end': 218.04,
#    'text': ' Of course.',
#    'tokens': [2720, 1164, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 93,
#    'seek': 20212,
#    'start': 218.04,
#    'end': 219.04000000000002,
#    'text': " That's why I like about it.",
#    'tokens': [663, 311, 983, 286, 411, 466, 309, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 94,
#    'seek': 20212,
#    'start': 219.04000000000002,
#    'end': 220.04000000000002,
#    'text': " I'm going to skip.",
#    'tokens': [286, 478, 516, 281, 10023, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 95,
#    'seek': 20212,
#    'start': 220.04000000000002,
#    'end': 224.12,
#    'text': ' What particular sectors or names come to mind for young investors with a 35 to 40-year',
#    'tokens': [708,
#     1729,
#     18373,
#     420,
#     5288,
#     808,
#     281,
#     1575,
#     337,
#     2037,
#     11519,
#     365,
#     257,
#     6976,
#     281,
#     3356,
#     12,
#     5294],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 96,
#    'seek': 20212,
#    'start': 224.12,
#    'end': 225.12,
#    'text': ' time horizon?',
#    'tokens': [565, 18046, 30],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 97,
#    'seek': 20212,
#    'start': 225.12,
#    'end': 226.12,
#    'text': ' Easy.',
#    'tokens': [16002, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 98,
#    'seek': 20212,
#    'start': 226.12,
#    'end': 227.12,
#    'text': " I don't know.",
#    'tokens': [286, 500, 380, 458, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 99,
#    'seek': 20212,
#    'start': 227.12,
#    'end': 228.12,
#    'text': ' I have no idea.',
#    'tokens': [286, 362, 572, 1558, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 100,
#    'seek': 20212,
#    'start': 228.12,
#    'end': 229.12,
#    'text': ' You could say technology.',
#    'tokens': [509, 727, 584, 2899, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 101,
#    'seek': 20212,
#    'start': 229.12,
#    'end': 230.12,
#    'text': " That'd be an easy one.",
#    'tokens': [663, 1116, 312, 364, 1858, 472, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 102,
#    'seek': 20212,
#    'start': 230.12,
#    'end': 231.12,
#    'text': ' Who knows what the companies are going to be?',
#    'tokens': [2102, 3255, 437, 264, 3431, 366, 516, 281, 312, 30],
#    'temperature': 0.0,
#    'avg_logprob': -0.23290008464187542,
#    'compression_ratio': 1.6309859154929578,
#    'no_speech_prob': 0.0005356372566893697},
#   {'id': 103,
#    'seek': 23112,
#    'start': 231.12,
#    'end': 232.12,
#    'text': ' There was this book I read.',
#    'tokens': [821, 390, 341, 1446, 286, 1401, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 104,
#    'seek': 23112,
#    'start': 232.12,
#    'end': 234.88,
#    'text': ' My brother got it for me for Christmas one year in 2007.',
#    'tokens': [1222,
#     3708,
#     658,
#     309,
#     337,
#     385,
#     337,
#     5272,
#     472,
#     1064,
#     294,
#     12656,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 105,
#    'seek': 23112,
#    'start': 234.88,
#    'end': 237.72,
#    'text': ' The Forever portfolio by James Altichur, while people.',
#    'tokens': [440,
#     30703,
#     12583,
#     538,
#     5678,
#     15992,
#     480,
#     374,
#     11,
#     1339,
#     561,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 106,
#    'seek': 23112,
#    'start': 237.72,
#    'end': 241.24,
#    'text': ' He picked these stocks that you could hold forever for decades and decades.',
#    'tokens': [634,
#     6183,
#     613,
#     12966,
#     300,
#     291,
#     727,
#     1797,
#     5680,
#     337,
#     7878,
#     293,
#     7878,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 107,
#    'seek': 23112,
#    'start': 241.24,
#    'end': 244.4,
#    'text': " Most of the stocks you've never heard of today because things changed.",
#    'tokens': [4534,
#     295,
#     264,
#     12966,
#     291,
#     600,
#     1128,
#     2198,
#     295,
#     965,
#     570,
#     721,
#     3105,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 108,
#    'seek': 23112,
#    'start': 244.4,
#    'end': 246.56,
#    'text': ' It was right before the Great Recession.',
#    'tokens': [467, 390, 558, 949, 264, 3769, 1300, 29881, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 109,
#    'seek': 23112,
#    'start': 246.56,
#    'end': 248.52,
#    'text': ' Then you had all this other stuff happen afterwards.',
#    'tokens': [1396, 291, 632, 439, 341, 661, 1507, 1051, 10543, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 110,
#    'seek': 23112,
#    'start': 248.52,
#    'end': 250.44,
#    'text': " All the stocks that end up doing well, you wouldn't have picked.",
#    'tokens': [1057,
#     264,
#     12966,
#     300,
#     917,
#     493,
#     884,
#     731,
#     11,
#     291,
#     2759,
#     380,
#     362,
#     6183,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 111,
#    'seek': 23112,
#    'start': 250.44,
#    'end': 254.56,
#    'text': ' Even picking out a decade and a half later is harder than three to four decades.',
#    'tokens': [2754,
#     8867,
#     484,
#     257,
#     10378,
#     293,
#     257,
#     1922,
#     1780,
#     307,
#     6081,
#     813,
#     1045,
#     281,
#     1451,
#     7878,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 112,
#    'seek': 23112,
#    'start': 254.56,
#    'end': 259.64,
#    'text': ' John throw up this chart of the biggest stocks in the S&P going back to 1980.',
#    'tokens': [2619,
#     3507,
#     493,
#     341,
#     6927,
#     295,
#     264,
#     3880,
#     12966,
#     294,
#     264,
#     318,
#     5,
#     47,
#     516,
#     646,
#     281,
#     13626,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.25935529407701996,
#    'compression_ratio': 1.6593406593406594,
#    'no_speech_prob': 0.00018519593868404627},
#   {'id': 113,
#    'seek': 25964,
#    'start': 259.64,
#    'end': 263.44,
#    'text': ' You can see here in 1980, it was basically all energy stocks.',
#    'tokens': [509,
#     393,
#     536,
#     510,
#     294,
#     13626,
#     11,
#     309,
#     390,
#     1936,
#     439,
#     2281,
#     12966,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21611001624824097,
#    'compression_ratio': 1.7672413793103448,
#    'no_speech_prob': 0.00021648473921231925},
#   {'id': 114,
#    'seek': 25964,
#    'start': 263.44,
#    'end': 266.2,
#    'text': ' These stocks have turned over so many times.',
#    'tokens': [1981, 12966, 362, 3574, 670, 370, 867, 1413, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21611001624824097,
#    'compression_ratio': 1.7672413793103448,
#    'no_speech_prob': 0.00021648473921231925},
#   {'id': 115,
#    'seek': 25964,
#    'start': 266.2,
#    'end': 267.2,
#    'text': " It's so hard to pick.",
#    'tokens': [467, 311, 370, 1152, 281, 1888, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.21611001624824097,
#    'compression_ratio': 1.7672413793103448,
#    'no_speech_prob': 0.00021648473921231925},
# ...
#    'tokens': [400, 291, 658, 613, 561, 11, 436, 445, 4700, 300, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 575,
#    'seek': 142356,
#    'start': 1425.48,
#    'end': 1428.84,
#    'text': " So, you know, if that's the type of client that I'm dealing with, you know, the conversation",
#    'tokens': [407,
#     11,
#     291,
#     458,
#     11,
#     498,
#     300,
#     311,
#     264,
#     2010,
#     295,
#     6423,
#     300,
#     286,
#     478,
#     6260,
#     365,
#     11,
#     291,
#     458,
#     11,
#     264,
#     3761],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 576,
#    'seek': 142356,
#    'start': 1428.84,
#    'end': 1431.3999999999999,
#    'text': " is going to lean that way and there's nothing wrong with that.",
#    'tokens': [307,
#     516,
#     281,
#     11659,
#     300,
#     636,
#     293,
#     456,
#     311,
#     1825,
#     2085,
#     365,
#     300,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 577,
#    'seek': 142356,
#    'start': 1431.3999999999999,
#    'end': 1435.9199999999998,
#    'text': " There's nothing, you know, we can, you know, we can gear towards that type of conversation",
#    'tokens': [821,
#     311,
#     1825,
#     11,
#     291,
#     458,
#     11,
#     321,
#     393,
#     11,
#     291,
#     458,
#     11,
#     321,
#     393,
#     7394,
#     3030,
#     300,
#     2010,
#     295,
#     3761],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 578,
#    'seek': 142356,
#    'start': 1435.9199999999998,
#    'end': 1438.04,
#    'text': " if it's required for the person that we're dealing with.",
#    'tokens': [498,
#     309,
#     311,
#     4739,
#     337,
#     264,
#     954,
#     300,
#     321,
#     434,
#     6260,
#     365,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 579,
#    'seek': 142356,
#    'start': 1438.04,
#    'end': 1441.24,
#    'text': " Duncan, I'm not going to make a coach K Duke reference here because I know it's a touchy",
#    'tokens': [31942,
#     11,
#     286,
#     478,
#     406,
#     516,
#     281,
#     652,
#     257,
#     6560,
#     591,
#     17380,
#     6408,
#     510,
#     570,
#     286,
#     458,
#     309,
#     311,
#     257,
#     2557,
#     88],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 580,
#    'seek': 142356,
#    'start': 1441.24,
#    'end': 1442.24,
#    'text': ' subject right now.',
#    'tokens': [3983, 558, 586, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 581,
#    'seek': 142356,
#    'start': 1442.24,
#    'end': 1443.24,
#    'text': " I didn't realize.",
#    'tokens': [286, 994, 380, 4325, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 582,
#    'seek': 142356,
#    'start': 1443.24,
#    'end': 1444.24,
#    'text': " It's rough.",
#    'tokens': [467, 311, 5903, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 583,
#    'seek': 142356,
#    'start': 1444.24,
#    'end': 1445.24,
#    'text': ' Yeah.',
#    'tokens': [865, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 584,
#    'seek': 142356,
#    'start': 1445.24,
#    'end': 1446.24,
#    'text': " It's been rough.",
#    'tokens': [467, 311, 668, 5903, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 585,
#    'seek': 142356,
#    'start': 1446.24,
#    'end': 1447.24,
#    'text': " It's been rough.",
#    'tokens': [467, 311, 668, 5903, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 586,
#    'seek': 142356,
#    'start': 1447.24,
#    'end': 1448.24,
#    'text': " It's a tough way for them to go out.",
#    'tokens': [467, 311, 257, 4930, 636, 337, 552, 281, 352, 484, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 587,
#    'seek': 142356,
#    'start': 1448.24,
#    'end': 1450.24,
#    'text': ' But literally, the worst team they could have lost to, you know, everyone knows I guess.',
#    'tokens': [583,
#     3736,
#     11,
#     264,
#     5855,
#     1469,
#     436,
#     727,
#     362,
#     2731,
#     281,
#     11,
#     291,
#     458,
#     11,
#     1518,
#     3255,
#     286,
#     2041,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 588,
#    'seek': 142356,
#    'start': 1450.24,
#    'end': 1452.24,
#    'text': ' But yeah, that had to be tough.',
#    'tokens': [583, 1338, 11, 300, 632, 281, 312, 4930, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 589,
#    'seek': 142356,
#    'start': 1452.24,
#    'end': 1453.24,
#    'text': ' All right.',
#    'tokens': [1057, 558, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.221750611240424,
#    'compression_ratio': 1.9689265536723164,
#    'no_speech_prob': 0.0006665232940576971},
#   {'id': 590,
#    'seek': 145324,
#    'start': 1453.24,
#    'end': 1454.48,
#    'text': ' Thanks to Matt for stepping in here.',
#    'tokens': [2561, 281, 7397, 337, 16821, 294, 510, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 591,
#    'seek': 145324,
#    'start': 1454.48,
#    'end': 1460.32,
#    'text': " I've been in this office for six years, seven years now almost and I've never lost power",
#    'tokens': [286,
#     600,
#     668,
#     294,
#     341,
#     3398,
#     337,
#     2309,
#     924,
#     11,
#     3407,
#     924,
#     586,
#     1920,
#     293,
#     286,
#     600,
#     1128,
#     2731,
#     1347],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 592,
#    'seek': 145324,
#    'start': 1460.32,
#    'end': 1461.32,
#    'text': ' before.',
#    'tokens': [949, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 593,
#    'seek': 145324,
#    'start': 1461.32,
#    'end': 1462.32,
#    'text': ' Yeah.',
#    'tokens': [865, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 594,
#    'seek': 145324,
#    'start': 1462.32,
#    'end': 1463.32,
#    'text': ' Glad I could be the one on here today to explain another time.',
#    'tokens': [28301,
#     286,
#     727,
#     312,
#     264,
#     472,
#     322,
#     510,
#     965,
#     281,
#     2903,
#     1071,
#     565,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 595,
#    'seek': 145324,
#    'start': 1463.32,
#    'end': 1464.32,
#    'text': ' I think Matt was stepping in.',
#    'tokens': [286, 519, 7397, 390, 16821, 294, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 596,
#    'seek': 145324,
#    'start': 1464.32,
#    'end': 1465.32,
#    'text': ' Yeah.',
#    'tokens': [865, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 597,
#    'seek': 145324,
#    'start': 1465.32,
#    'end': 1471.1200000000001,
#    'text': ' We got to mention no portfolio rescue next week because Duncan and I will be in Miami',
#    'tokens': [492,
#     658,
#     281,
#     2152,
#     572,
#     12583,
#     13283,
#     958,
#     1243,
#     570,
#     31942,
#     293,
#     286,
#     486,
#     312,
#     294,
#     18367],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 598,
#    'seek': 145324,
#    'start': 1471.1200000000001,
#    'end': 1474.8,
#    'text': ' recording a live additional mental spirits that if we figured out, can hopefully go up',
#    'tokens': [6613,
#     257,
#     1621,
#     4497,
#     4973,
#     16388,
#     300,
#     498,
#     321,
#     8932,
#     484,
#     11,
#     393,
#     4696,
#     352,
#     493],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 599,
#    'seek': 145324,
#    'start': 1474.8,
#    'end': 1477.48,
#    'text': ' on this channel at some point.',
#    'tokens': [322, 341, 2269, 412, 512, 935, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 600,
#    'seek': 145324,
#    'start': 1477.48,
#    'end': 1478.8,
#    'text': ' Keep those questions and comments coming.',
#    'tokens': [5527, 729, 1651, 293, 3053, 1348, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 601,
#    'seek': 145324,
#    'start': 1478.8,
#    'end': 1483.2,
#    'text': ' Remember, ask the compound show at gmail.com.',
#    'tokens': [5459, 11, 1029, 264, 14154, 855, 412, 290, 11799, 13, 1112, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.26938956124441965,
#    'compression_ratio': 1.6307692307692307,
#    'no_speech_prob': 0.002082651248201728},
#   {'id': 602,
#    'seek': 148320,
#    'start': 1483.2,
#    'end': 1484.2,
#    'text': ' Thanks guys.',
#    'tokens': [2561, 1074, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 603,
#    'seek': 148320,
#    'start': 1484.2,
#    'end': 1485.88,
#    'text': " Thanks for watching and we're back in two weeks.",
#    'tokens': [2561, 337, 1976, 293, 321, 434, 646, 294, 732, 3259, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 604,
#    'seek': 148320,
#    'start': 1485.88,
#    'end': 1486.88,
#    'text': ' One other thing.',
#    'tokens': [1485, 661, 551, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 605,
#    'seek': 148320,
#    'start': 1486.88,
#    'end': 1489.6000000000001,
#    'text': " Don't forget, we're also available as a podcast wherever you listen to podcasts.",
#    'tokens': [1468,
#     380,
#     2870,
#     11,
#     321,
#     434,
#     611,
#     2435,
#     382,
#     257,
#     7367,
#     8660,
#     291,
#     2140,
#     281,
#     24045,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 606,
#    'seek': 148320,
#    'start': 1489.6000000000001,
#    'end': 1492.92,
#    'text': " So make sure you've subscribed and give us a rating, all that kind of stuff.",
#    'tokens': [407,
#     652,
#     988,
#     291,
#     600,
#     16665,
#     293,
#     976,
#     505,
#     257,
#     10990,
#     11,
#     439,
#     300,
#     733,
#     295,
#     1507,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 607,
#    'seek': 148320,
#    'start': 1492.92,
#    'end': 1493.92,
#    'text': ' It helps a lot.',
#    'tokens': [467, 3665, 257, 688, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 608,
#    'seek': 148320,
#    'start': 1493.92,
#    'end': 1494.92,
#    'text': ' So yeah.',
#    'tokens': [407, 1338, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 609,
#    'seek': 148320,
#    'start': 1494.92,
#    'end': 1495.92,
#    'text': ' Thanks a lot.',
#    'tokens': [2561, 257, 688, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 610,
#    'seek': 148320,
#    'start': 1495.92,
#    'end': 1497.4,
#    'text': ' We have a fancy new cover with Duncan and I on it.',
#    'tokens': [492,
#     362,
#     257,
#     10247,
#     777,
#     2060,
#     365,
#     31942,
#     293,
#     286,
#     322,
#     309,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 611,
#    'seek': 148320,
#    'start': 1497.4,
#    'end': 1498.4,
#    'text': ' Our pictures.',
#    'tokens': [2621, 5242, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 612,
#    'seek': 148320,
#    'start': 1498.4,
#    'end': 1499.4,
#    'text': ' It looks amazing.',
#    'tokens': [467, 1542, 2243, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 613,
#    'seek': 148320,
#    'start': 1499.4,
#    'end': 1500.4,
#    'text': " It's true.",
#    'tokens': [467, 311, 2074, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 614,
#    'seek': 148320,
#    'start': 1500.4,
#    'end': 1501.4,
#    'text': " It's feel famous.",
#    'tokens': [467, 311, 841, 4618, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 615,
#    'seek': 148320,
#    'start': 1501.4,
#    'end': 1502.4,
#    'text': ' All right.',
#    'tokens': [1057, 558, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 616,
#    'seek': 148320,
#    'start': 1502.4,
#    'end': 1503.4,
#    'text': ' Thanks everyone for watching.',
#    'tokens': [2561, 1518, 337, 1976, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 617,
#    'seek': 148320,
#    'start': 1503.4,
#    'end': 1503.4,
#    'text': ' See ya.',
#    'tokens': [3008, 2478, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.24556968952047414,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.00046541329356841743},
#   {'id': 618,
#    'seek': 150340,
#    'start': 1503.4,
#    'end': 1515.6000000000001,
#    'text': ' Bye.',
#    'tokens': [50364, 4621, 13, 50974],
#    'temperature': 0.0,
#    'avg_logprob': -0.9830149650573731,
#    'compression_ratio': 0.3333333333333333,
#    'no_speech_prob': 0.004109111614525318}],
#  'language': 'en'}

# %%
output['text']
# Out:
# " Welcome back to Portfolio Rescue. I'll show you where we take questions straight from you. We've got a lot of questions like I said last week. We're going to try to do a lightning round today. Before we get to that, I remember asked the compound show at gmail.com Duncan. Last week's show I mentioned the 50-30-20 rule. I said, I don't know where it comes from. A lot of these things in finance, they just sound good and they stick like the 60-40 Portfolio. No one actually knows who started that or where it came from. We all just kind of subscribed to it. But the 50-30-20 rule. Last Thursday after we did the show, I was reading a book at night, kind of read before I go to bed. I was reading this book called Die Was Zero by a guy named Bill Perkins. The whole idea is if you have a lot of money, your hope should be to spend that money, either give it away to charity or spend it all on experiences before you die. Interesting concept. A lot. You were talking about animal spirits. Yeah, one of the chapters of that same book. He said, the 50-30-20 rule comes from a very well-known politician today. It's a woman. Do you have any guesses? A politician came up with this. Elizabeth Warren? Elizabeth Warren. Before Shanner Pilatex, Warren had been a law professor with special expertise in bankruptcy in Coral Books about why middle-class Americans go broke and how to avoid that dismal fate. She suggested the 50-30-20 rule, which she called the balanced money formula as a way to help people maintain financial stability. It had no idea. This was Elizabeth Warren rule. Yeah. It's going to be crazy. All right. So we're just going to get right into it because last week we mentioned we're overflowing with questions. So we're going to do something about lightning around today. Rapid fire. We still have an expert coming out at the end of the show. But I think we did seven or eight questions right away. We're just going to go rapid fire. We had a lot of them and I don't need spend a ton of time. So I think Doug has got a timer for me, even. Yeah. He's going to have a timer too long. I'm going to time you on the Apple Watch and I've actually got a sound effect timer and buzzer. All right. Question one. OK. OK. OK. Can you please explain how the Fed raising interest rates fights off inflation? I understand it can slow down the housing and car market. But how does it impact other goods? Bikes, dishwashers, clothes, et cetera, especially when there are supply side issues? Would the Fed be raising rates if demand and supply were at equilibrium? This is true that the Fed can't produce more. Some of the conductors, they can't build more houses. They can't put more cars in the lots. Here's one of the things they can do. They can make money more expensive. So maybe people don't buy a second home because instead of 3% it's 5%, I'm not going to pay for another house here. I'm not going to buy a vacation home. Maybe some companies cut back on investments because the hurdle rate is not much higher. I think it's also psychological component to this. People see asset prices falling and they might cut back on spending. He'll Dudley who's a former New York Fed chair, wrote yesterday in Bloomberg. In contrast to many other countries, the US economy doesn't respond directly to the level of short-term interest rates. The home borrowers aren't affected because they have long-term fixed rate mortgages. Again, in contrast to many other countries, US households do hold a significant amount of wealth and equities. As a result, their sensitive financial conditions, equity price influence how wealthy people feel and how willing they are to spend rather than save. He's saying the Fed has to jack up rates to lower the stock market. That makes sense. I don't know what the unintended consequences are going to be. Is a recession going to be better than high inflation? I think we might get a chance to find out if the Fed has their way. The Fed can't make supply chain issues go bett ...

# %%
import csv

# create a new pandas dataframe
df = pd.DataFrame(columns=['episode', 'url', 'start_timestamp', 'start', 'end', 'question', 'context'])

# index to keep track of current row
i = 0

with open('financial_advisor.csv') as csv_file:
    reader = csv.reader(csv_file)

    # skip the header row in the csv file
    next(reader)

    for row in reader:
        # assign each column in the row to a variable and split questions on carriage return
        episode, url, questions = row
        question_list = questions.split("\n")

        # for each question in the list, extract the timestamp and convert it to seconds for youtube
        for question in question_list:
          pieces = question.split('-')
          timestamp = pieces[0]
          minutes, seconds = timestamp.split(':')
          seconds = int(seconds) + (int(minutes.lstrip()) * 60)

          # add a new row to the dataframe
          df.loc[i] = [episode, url, timestamp, seconds, seconds, " ".join(pieces[1:]), ""]

          try:
            df.loc[i-1]['end'] = df.loc[i]['start']
          except:
            print(f"skipping row {i} because there is no previous row")

          i+=1

          df['end'][df['end'] < df['start']] = 0
          df['end'][df['start'] == df['end']] = 0

df.to_csv("questions.csv")
# Out:
# skipping row 0 because there is no previous row

# %%
import pandas as pd

df = pd.read_csv('questions.csv')
df
# Out:
#      Unnamed: 0     episode                                          url  \
# 0             0   Episode 1  https://www.youtube.com/watch?v=0z49u_b6PmE
# 1             1   Episode 1  https://www.youtube.com/watch?v=0z49u_b6PmE
# 2             2   Episode 1  https://www.youtube.com/watch?v=0z49u_b6PmE
# 3             3   Episode 2  https://www.youtube.com/watch?v=IDGnZ2AErBg
# 4             4   Episode 2  https://www.youtube.com/watch?v=IDGnZ2AErBg
# ..          ...         ...                                          ...
# 293         293  Episode 61  https://www.youtube.com/watch?v=dYQAYc26bm0
# 294         294  Episode 61  https://www.youtube.com/watch?v=dYQAYc26bm0
# 295         295  Episode 61  https://www.youtube.com/watch?v=dYQAYc26bm0
# 296         296  Episode 61  https://www.youtube.com/watch?v=dYQAYc26bm0
# 297         297  Episode 61  https://www.youtube.com/watch?v=dYQAYc26bm0
#
#     start_timestamp  start   end  \
# 0            03:07     187   415
# 1            06:55     415   669
# 2            11:09     669     0
# 3            01:04      64   366
# 4            06:06     366   566
# ..              ...    ...   ...
# 293          02:56     176   443
# 294          07:23     443   670
# 295          11:10     670  1103
# 296          18:23    1103  1698
# 297          28:18    1698     0
#
#                                               question  context
# 0     What's the best way to reallocate a portfolio...      NaN
# 1     What do I do once I cross the Roth IRA income...      NaN
# 2     Once I have maxed out my retiremenet accounts...      NaN
# 3                                 Saving vs. Investing      NaN
# 4     If Baby Boomers are shifting from net investo...      NaN
# ..                                                 ...      ...
# 293             Adding bonds to a 100% stock portfolio      NaN
# 294   Is having a pension and annuity a substitute ...      NaN
# 295                 Can the stock market grow forever?      NaN
# 296                              Whole life insurance.      NaN
# 297                                   Saving for kids.      NaN
#
# [298 rows x 8 columns]

# %%
# Let's just get the questions for a single episode and make this work before we download and transcribe all episodes in bulk
episode = df[df['episode'] == 'Episode 22'].copy()
episode
# Out:
#     Unnamed: 0     episode                                          url  \
# 83          83  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 84          84  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 85          85  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 86          86  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 87          87  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 88          88  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 89          89  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 90          90  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 91          91  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
#
#    start_timestamp  start   end  \
# 83          01:58     118   210
# 84          03:30     210   316
# 85          05:16     316   618
# 86          10:18     618   717
# 87          11:57     717   805
# 88          13:25     805   879
# 89          14:39     879  1039
# 90          17:19    1039  1275
# 91          21:15    1275     0
#
#                                              question  context
# 83   How does the fed raising interest rates fight...      NaN
# 84   What particular sectors/names do you find mos...      NaN
# 85   What will bring more value in the long run fo...      NaN
# 86   Would you recommend focusing on paying off my...      NaN
# 87                             Paying off a mortgage.      NaN
# 88            What happens when the Fed raises rates?      NaN
# 89   I’m 44 and have a net worth of around $425K. ...      NaN
# 90   What are some good questions to ask when sele...      NaN
# 91    At interest rates so low, should I instead t...      NaN

# %%
def is_part_of_question(segment, start, end):
    if segment['start'] > start:
      if segment['end'] < end or end == 0:
          return True

    return False

def get_question_context(row):
     global output

     question_segments = list(filter(lambda segment: is_part_of_question(segment, row['start'], row['end']), output['segments']))
     # include question from timestamp in the context
     context = row['question']
     for segment in question_segments:
         context += segment['text']

     return context

episode['context'] = episode.apply(get_question_context, axis=1)

episode
# Out:
#     Unnamed: 0     episode                                          url  \
# 83          83  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 84          84  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 85          85  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 86          86  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 87          87  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 88          88  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 89          89  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 90          90  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 91          91  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
#
#    start_timestamp  start   end  \
# 83          01:58     118   210
# 84          03:30     210   316
# 85          05:16     316   618
# 86          10:18     618   717
# 87          11:57     717   805
# 88          13:25     805   879
# 89          14:39     879  1039
# 90          17:19    1039  1275
# 91          21:15    1275     0
#
#                                              question  \
# 83   How does the fed raising interest rates fight...
# 84   What particular sectors/names do you find mos...
# 85   What will bring more value in the long run fo...
# 86   Would you recommend focusing on paying off my...
# 87                             Paying off a mortgage.
# 88            What happens when the Fed raises rates?
# 89   I’m 44 and have a net worth of around $425K. ...
# 90   What are some good questions to ask when sele...
# 91    At interest rates so low, should I instead t...
#
#                                               context
# 83   How does the fed raising interest rates fight...
# 84   What particular sectors/names do you find mos...
# 85   What will bring more value in the long run fo...
# 86   Would you recommend focusing on paying off my...
# 87   Paying off a mortgage. roughly 24 years left,...
# 88   What happens when the Fed raises rates? Okay,...
# 89   I’m 44 and have a net worth of around $425K. ...
# 90   What are some good questions to ask when sele...
# 91    At interest rates so low, should I instead t...

# %%
from openai.embeddings_utils import get_embedding

#get_embedding(episode.iloc[0]['context'], engine='text-embedding-ada-002')

episode['embedding'] = episode['context'].apply(lambda row: get_embedding(row, engine='text-embedding-ada-002'))
episode.to_csv('question_embeddings.csv')

# %%
from openai.embeddings_utils import cosine_similarity

question = "Should I buy a house with cash?"
question_vector = get_embedding(question, engine='text-embedding-ada-002')

episode["similarities"] = episode['embedding'].apply(lambda x: cosine_similarity(x, question_vector))
episode = episode.sort_values("similarities", ascending=False).head(4)

episode
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9d4efb561454> in <module>
# ----> 1 from openai.embeddings_utils import cosine_similarity
#       2
#       3 question = "What do you think of Elon buying Twitter?"
#       4 question_vector = get_embedding(question, engine='text-embedding-ada-002')
#       5
#
# ModuleNotFoundError: No module named 'openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
episode.to_csv("sorted.csv")

# %%
context = []
for i, row in episode.iterrows():
  context.append(row['context'])

context
# Out:
# ["  At interest rates so low, should I instead take a loan, finance the house and invest my capital in the stock market? Okay. So last but not least, I'm in my 30s and can now afford to buy a house full cash without taking any debt. However, with interest rates so low and they wrote this one a while back, but should I take a loan anyway and finance the house and invest my capital in the stock market? I think this is interesting that rates could change the story. Going from a 3% mortgage rate to a 5%, that hurdle changes. So nine months ago, I would have said you'd be nuts to pay in full cash now. Maybe it kind of makes sense. But first of all, who does this person for having that amount of money? I don't know where they live to be able to buy in cash, but that's great. But so Matt, you're thinking through this type of decision with a client. And this is the kind of thing where there really is no right or wrong answer. A lot of this is personality driven and depending on what the person wants to get out of it. So how do you help someone work through a big decision like this? Because this is a huge, we're talking about a huge lump sum of money, six or seven figures here, potentially depending on how much home they're buying. Yeah, like a lot of these questions, there are a lot of qualitative elements that need to be addressed as opposed to just where can I make the most money? What should I do in that sense? It's really about what's the opportunity cost, right? What are the goals do you have that this money you could be throwing into equity in your home could be used for? Do you have kids? Do you want to help them get to college and go to college? If they're young, you might want a front load of 529 plan and you've some of this money for that. So that's just one example. But there's a lot of things that play into this as opposed to just, hey, I saved up the money. Should I just throw it on to my house? I also think interest. Especially when your young borrowing money makes more sense to me because especially with the house that offers more liquidity, flexibility, you can't really spend your house in a pinch, you could obviously borrow against it, but having some flexibility to do something with that cash and then still having that cash, if you realize a few years down the road, like I made a mistake here, you can still pay it off eventually, right? You still have that cash somewhere. So I think that is the kind of thing where it's hard to take that one back if you buy the house in all cash. Obviously, maybe one of the things now is, well, if you're getting into a bidding or having all cash, could make more sense and help. But I think especially when you're young, you lose some flexibility by just having it paid off. Definitely. I mean, the interest rate part of it is pretty big, I think. I mean, a couple months ago, you know, it's like you said, it's more obvious, but still, even with where we're at today, you want the flexibility. You want to be able to fund other parts of your life. Having everything tied up in equity, you know, is, you know, it could be restraining a little bit. And you got these people, they just hate that. So, you know, if that's the type of client that I'm dealing with, you know, the conversation is going to lean that way and there's nothing wrong with that. There's nothing, you know, we can, you know, we can gear towards that type of conversation if it's required for the person that we're dealing with. Duncan, I'm not going to make a coach K Duke reference here because I know it's a touchy subject right now. I didn't realize. It's rough. Yeah. It's been rough. It's been rough. It's a tough way for them to go out. But literally, the worst team they could have lost to, you know, everyone knows I guess. But yeah, that had to be tough. All right. Thanks to Matt for stepping in here. I've been in this office for six years, seven years now almost and I've never lost power before. Yeah. Glad I could be the one o ...
#  " What will bring more value in the long run for a child? for a fancy private college that totals $250,000 or sending them to a mid-tier public school on a full ride and putting that $250,000 into an index fund for their retirement. Listen, this is the type of question that is way easier to answer as an older person than a younger person. Like, when you're older, you can easily say, like, don't spend a lot of money on a wedding because that's a waste of money, right? Or why would you spend all this money on college when you can just invest it and start a business and go bet on yourself? Like, that's way easier to say as a younger person. Like, hey, outside of the top 15 to 20 schools, it doesn't matter where your degree came from as long as you're going, right? But I think you use this as a teaching moment, right? So, you can say option one, you go to a really expensive school, but you forego this potential will financially be set up as a young person and maybe buying your first house or paying for a wedding or whatever you want to do with the money retiring early. Or you go to a state school, but here's what you're giving up. You're not going to go to a nice expensive school that you want to. You could be missing out on experiences. And which one do you regret more? You put all the information out there for me. You just as a teaching opportunity, maybe talk about compound interest a little bit before their eyes glaze over. But I say if you're going to do this, don't scold someone, don't force them, give them all the information and let them make the decisions themselves, right? Because again, your decision at A to 18, maybe they say, you know what? I'll make my own money something. I don't need your money. I want to go to this school because my friends are going there because that is an awesome program that I want to do. Whatever. So, I think that's what you do. You help them make an adult decision and let them figure out which path is better for them. Yeah, now that sounds like good advice. Also, yeah, so much of college is about what you make it. Like, they're brilliant people who go to, you know, like less prestigious schools and end up, you know, being very successful. Well, my favorite one is. The private school doesn't really need that much. Oh, did we lose you been? Oh, I think we might have lost, lost been there for a second. All right, well, let's give it a second to see if he comes back. And if he doesn't, then maybe I'll bring Matt back in. All right. So, we'll switch this up a little bit. So we'll go ahead and jump into Matt. So Matt, get ready. I'm going to get your opinion on this. What do you think about this question between the public mid-tier school and a private school? Also, I should introduce you. This is a mad-worthy. Young advisor extraordinaire at Reholtz-Wealth. We're going to surprise you at question 8, but I'll go and bring you in. Of course, don't we curve ball right off the bat here. Love it. So I agree with Bennett. It's much easier to answer this as an older person, just saying, having gone through the experience of paying for these types of big events and saying, well, did I really need that? But the experiences are worth something. So in terms of where are you going to go to school, as long as you get a good education, I think, and even if it's a mid-tier school, if you're not paying as much money, you'll probably end up OK at the end of the day. You'll end up all right. So, don't kill yourself over. Don't feel like you have to spend godly amounts of money on school, but also at the same time you want the experience, right? You want to be able to learn the things that don't necessarily happen in college, meeting people, networking, all that type of stuff is important. And when we're older, it's easier to say, did I really need that? But. Right. Yeah, hindsight. People aren't happy with their careers. They're always going to work back and be like, oh, I spent too much on college. But I think t ...
#  " Would you recommend focusing on paying off my student loans first? Or should I begin building my portfolio?  I love it. The surprise is over. OK. So, I have next, long time viewer of the show, web all the content you put out. I'm 23 and just graduated from college. I landed my first job at a financial services firm and I'm wondering how I should allocate my earnings. Would you recommend focusing on paying off my student loans first around $30,000 or building up my retirement portfolio? My boring answer to this one is I like the idea of splitting it up because I think that's the simplest way to go about it. And I think building those financial habits early and saving important. Now, it could be one of these people that just loves paying off debt because you hate it so much. Right, Duncan, I can't remember. Are you a Duke or North Carolina fan because you're from North Carolina? I'm a Duke fan. OK. So, some people hate debt as much as people outside of Durham, North Carolina hate Coach Kay and Duke, right? Oh, wow. Yeah. What's pretty hydraulic? It's pretty hydraulic. Come on. It was in the news a lot. But I'm just saying, if you really want to these people that just hate debt and cannot stand it and it's going to keep you up at night, pay it off. But I like the idea of splitting it up and building those savings habits while you pay off the debt. And then when the debts paid off, roll that. Those payments into your savings. For sure. I agree. I mean, you guys start contributing to the 401K, at least. I think a little bit, you don't have to do a lot, but you can do both at the same time. There's no reason why not. Yes, at least get your match. All right. Was it? So, right on time. There we go. So, one thing I had to add to that is just, yeah, the Dave Ramsey School of like no debt ever kind of thing. That always, to me, is kind of annoying because it's like, well, you're basically telling a lot of people that they can't like go to college then if they can't take out student loan debt because you should never take out. Yeah, I feel like you're saying some people are so, so extreme about it. It's kind of off-putting. Yeah, that's a debt that's going to pay off for you. There's good and bad debt.",
#  " Paying off a mortgage. roughly 24 years left, and pays an extra $400 each month towards her principal. If she continues to prepay $400 towards her principal, she has about 16 years remaining. Her house has enjoyed strong appreciation in the past six years, about 85% according to Zilla. I told her I would show, I told her that I would slow pay the mortgage due to the phenomenal rate, plus significant appreciation, and invest the $400 a month in the stock market. What are your thoughts on this? I do think the rates matter in these things. I got my first interest rate I paid at my house like 6.5%. We ended up refinancing a few times to the point where we kept making the same payment and it was like double by the end. But then only sold our house after 10 years, I realized like, wait, what was that money doing for me? It was illicit, it was just sitting there. It wasn't that great. I think if you have that low of a payment and it's taxed advantage, I think you have to think about that in terms of how are the rest of your finances? Are you on track with your retirement savings? Could you be using this money for something better than a 2.8% repayment on your house? Some people just don't like debt. So if that's how you are, that's keeping you up at night and pay it off. But yeah, otherwise, there's probably other things you could be doing with it. That just takes a little bit more deeper dive into your full picture. It's a really low hurdle rate. Cool, we didn't even get to the buzzer on that one."]

# %%
text = "\n".join(context)
text
# Out:
# "  At interest rates so low, should I instead take a loan, finance the house and invest my capital in the stock market? Okay. So last but not least, I'm in my 30s and can now afford to buy a house full cash without taking any debt. However, with interest rates so low and they wrote this one a while back, but should I take a loan anyway and finance the house and invest my capital in the stock market? I think this is interesting that rates could change the story. Going from a 3% mortgage rate to a 5%, that hurdle changes. So nine months ago, I would have said you'd be nuts to pay in full cash now. Maybe it kind of makes sense. But first of all, who does this person for having that amount of money? I don't know where they live to be able to buy in cash, but that's great. But so Matt, you're thinking through this type of decision with a client. And this is the kind of thing where there really is no right or wrong answer. A lot of this is personality driven and depending on what the person wants to get out of it. So how do you help someone work through a big decision like this? Because this is a huge, we're talking about a huge lump sum of money, six or seven figures here, potentially depending on how much home they're buying. Yeah, like a lot of these questions, there are a lot of qualitative elements that need to be addressed as opposed to just where can I make the most money? What should I do in that sense? It's really about what's the opportunity cost, right? What are the goals do you have that this money you could be throwing into equity in your home could be used for? Do you have kids? Do you want to help them get to college and go to college? If they're young, you might want a front load of 529 plan and you've some of this money for that. So that's just one example. But there's a lot of things that play into this as opposed to just, hey, I saved up the money. Should I just throw it on to my house? I also think interest. Especially when your young borrowing money makes more sense to me because especially with the house that offers more liquidity, flexibility, you can't really spend your house in a pinch, you could obviously borrow against it, but having some flexibility to do something with that cash and then still having that cash, if you realize a few years down the road, like I made a mistake here, you can still pay it off eventually, right? You still have that cash somewhere. So I think that is the kind of thing where it's hard to take that one back if you buy the house in all cash. Obviously, maybe one of the things now is, well, if you're getting into a bidding or having all cash, could make more sense and help. But I think especially when you're young, you lose some flexibility by just having it paid off. Definitely. I mean, the interest rate part of it is pretty big, I think. I mean, a couple months ago, you know, it's like you said, it's more obvious, but still, even with where we're at today, you want the flexibility. You want to be able to fund other parts of your life. Having everything tied up in equity, you know, is, you know, it could be restraining a little bit. And you got these people, they just hate that. So, you know, if that's the type of client that I'm dealing with, you know, the conversation is going to lean that way and there's nothing wrong with that. There's nothing, you know, we can, you know, we can gear towards that type of conversation if it's required for the person that we're dealing with. Duncan, I'm not going to make a coach K Duke reference here because I know it's a touchy subject right now. I didn't realize. It's rough. Yeah. It's been rough. It's been rough. It's a tough way for them to go out. But literally, the worst team they could have lost to, you know, everyone knows I guess. But yeah, that had to be tough. All right. Thanks to Matt for stepping in here. I've been in this office for six years, seven years now almost and I've never lost power before. Yeah. Glad I could be the one on ...

# %%
context = text

context
# Out:
# "  At interest rates so low, should I instead take a loan, finance the house and invest my capital in the stock market? Okay. So last but not least, I'm in my 30s and can now afford to buy a house full cash without taking any debt. However, with interest rates so low and they wrote this one a while back, but should I take a loan anyway and finance the house and invest my capital in the stock market? I think this is interesting that rates could change the story. Going from a 3% mortgage rate to a 5%, that hurdle changes. So nine months ago, I would have said you'd be nuts to pay in full cash now. Maybe it kind of makes sense. But first of all, who does this person for having that amount of money? I don't know where they live to be able to buy in cash, but that's great. But so Matt, you're thinking through this type of decision with a client. And this is the kind of thing where there really is no right or wrong answer. A lot of this is personality driven and depending on what the person wants to get out of it. So how do you help someone work through a big decision like this? Because this is a huge, we're talking about a huge lump sum of money, six or seven figures here, potentially depending on how much home they're buying. Yeah, like a lot of these questions, there are a lot of qualitative elements that need to be addressed as opposed to just where can I make the most money? What should I do in that sense? It's really about what's the opportunity cost, right? What are the goals do you have that this money you could be throwing into equity in your home could be used for? Do you have kids? Do you want to help them get to college and go to college? If they're young, you might want a front load of 529 plan and you've some of this money for that. So that's just one example. But there's a lot of things that play into this as opposed to just, hey, I saved up the money. Should I just throw it on to my house? I also think interest. Especially when your young borrowing money makes more sense to me because especially with the house that offers more liquidity, flexibility, you can't really spend your house in a pinch, you could obviously borrow against it, but having some flexibility to do something with that cash and then still having that cash, if you realize a few years down the road, like I made a mistake here, you can still pay it off eventually, right? You still have that cash somewhere. So I think that is the kind of thing where it's hard to take that one back if you buy the house in all cash. Obviously, maybe one of the things now is, well, if you're getting into a bidding or having all cash, could make more sense and help. But I think especially when you're young, you lose some flexibility by just having it paid off. Definitely. I mean, the interest rate part of it is pretty big, I think. I mean, a couple months ago, you know, it's like you said, it's more obvious, but still, even with where we're at today, you want the flexibility. You want to be able to fund other parts of your life. Having everything tied up in equity, you know, is, you know, it could be restraining a little bit. And you got these people, they just hate that. So, you know, if that's the type of client that I'm dealing with, you know, the conversation is going to lean that way and there's nothing wrong with that. There's nothing, you know, we can, you know, we can gear towards that type of conversation if it's required for the person that we're dealing with. Duncan, I'm not going to make a coach K Duke reference here because I know it's a touchy subject right now. I didn't realize. It's rough. Yeah. It's been rough. It's been rough. It's a tough way for them to go out. But literally, the worst team they could have lost to, you know, everyone knows I guess. But yeah, that had to be tough. All right. Thanks to Matt for stepping in here. I've been in this office for six years, seven years now almost and I've never lost power before. Yeah. Glad I could be the one on ...

# %%
prompt = f"""Answer the following question using only the context below. Answer in the style of Ben Carlson a financial advisor and podcaster. If you don't know the answer for certain, say I don't know.

Context:
{context}

Q: {question}
A:"""

openai.Completion.create(
    prompt=prompt,
    temperature=1,
    max_tokens=500,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
    model=COMPLETIONS_MODEL
)["choices"][0]["text"].strip(" \n")
# Out:
# "I don't know. Elon is certainly a visionary, so I'm sure if he buys Twitter, he'll have plans for it. All I'd say is that if he does buy it, I hope he keeps it an independent platform, as opposed to making it part of another product. That's one of the cool aspects of Twitter, that it can give people an independent voice, no matter who they are. So, if it's not broken, don't fix it. Let's just see what Elon has in store."
